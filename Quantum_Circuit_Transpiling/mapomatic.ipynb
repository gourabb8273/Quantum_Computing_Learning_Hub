# %%
from qiskit.circuit.random import random_circuit
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

import mapomatic as mm

# %%
qc = random_circuit(num_qubits=10, depth=4, max_operands=2, measure=True)
qc.draw(fold=-1)
# Out:
#          ┌─────────────┐   ┌───────────────────┐                                                                                                                                  ┌─┐
#  q_0: ───┤0            ├───┤ R(4.0771,0.53079) ├───────────────────────────────────────────────────────────────────────■──────────────────────────────────────────■───────────────┤M├─────────────────────
#          │             │   └───────────────────┘┌──────────────────────────┐┌────────────┐                             │   ┌──────────────────────────┐┌───┐      │               └╥┘┌─┐
#  q_1: ───┤             ├────────────────────────┤0                         ├┤ Ry(4.4526) ├─────────────────────────────┼───┤ U3(1.4235,3.0593,5.8311) ├┤ S ├──────┼────────────────╫─┤M├──────────────────
#          │             │                        │                          │└────────────┘       ┌────────────┐        │   └────────────┬─────────────┘└─┬─┘      │       ┌──────┐ ║ └╥┘┌─┐
#  q_2: ───┤  Ryy(1.094) ├────────■───────────────┤  (XX+YY)(0.66004,3.7997) ├──────■──────────────┤ Rx(5.3099) ├────────┼────────────────┼────────────────┼────────┼───────┤1     ├─╫──╫─┤M├───────────────
#          │             │        │               │                          │┌─────┴──────┐       ├────────────┤        │                │                │      ┌─┴──┐    │      │ ║  ║ └╥┘┌─┐
#  q_3: ───┤             ├────────┼───────────────┤1                         ├┤ Ry(3.4694) ├───────┤ Ry(4.9545) ├────────┼────────────────┼────────────────┼──────┤ Sx ├────┤      ├─╫──╫──╫─┤M├────────────
#          │             │        │               └──────────────────────────┘└────────────┘       └────────────┘        │                │                │     ┌┴────┤    │      │ ║  ║  ║ └╥┘┌─┐
#  q_4: ───┤1            ├────────┼─────────────────────────────────────────────────■────────────────────────────────────┼────────────────■────────────────┼─────┤ Tdg ├────┤      ├─╫──╫──╫──╫─┤M├─────────
#       ┌──┴─────────────┴──┐     │               ┌─────────────────────────┐       │                                    │                                 │  ┌──┴─────┴───┐│      │ ║  ║  ║  ║ └╥┘┌─┐
#  q_5: ┤ U2(3.6869,4.1123) ├─────┼───────────────┤0                        ├───────┼────────────────────────────────────┼────────────────■────────────────┼──┤ Rx(3.0624) ├┤  Dcx ├─╫──╫──╫──╫──╫─┤M├──────
#       └───────────────────┘     │               │                         │       │       ┌─────────────────────────┐  │              ┌─┴─┐              │  └────┬─┬─────┘│      │ ║  ║  ║  ║  ║ └╥┘
#  q_6: ──────■───────────────────┼───────────────┤                         ├───────┼───────┤0                        ├──┼──────────────┤ S ├──────────────■───────┤M├──────┤      ├─╫──╫──╫──╫──╫──╫───────
#             │                   │ZZ(1.6859)     │  (XX+YY)(2.8156,2.6881) │       │       │  (XX+YY)(4.7583,5.4296) │  │          ┌───┴───┴────┐       ┌───┐     └╥┘      │      │ ║  ║  ║  ║  ║  ║ ┌─┐
#  q_7: ──────┼───────────────────■───────────────┤                         ├───────┼───────┤1                        ├──┼──────────┤ Rx(5.8282) ├───────┤ I ├──────╫───────┤      ├─╫──╫──╫──╫──╫──╫─┤M├───
#             │U1(2.184)                          │                         │       │       └─────────────────────────┘  │          └────────────┘       └───┘      ║       │      │ ║  ║  ║  ║  ║  ║ └╥┘┌─┐
#  q_8: ──────■───────────────────────────────────┤1                        ├───────┼────────────────────────────────────■──────────────────────────────────────────╫───────┤0     ├─╫──╫──╫──╫──╫──╫──╫─┤M├
#               ┌───┐                             └─────────────────────────┘     ┌─┴─┐                ┌───┐           ┌────┐            ┌─┐                        ║       └──────┘ ║  ║  ║  ║  ║  ║  ║ └╥┘
#  q_9: ────────┤ Z ├─────────────────────────────────────────────────────────────┤ H ├────────────────┤ X ├───────────┤ √X ├────────────┤M├────────────────────────╫────────────────╫──╫──╫──╫──╫──╫──╫──╫─
#               └───┘                                                             └───┘                └───┘           └────┘            └╥┘                        ║                ║  ║  ║  ║  ║  ║  ║  ║
# c: 10/══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩═════════════════════════╩════════════════╩══╩══╩══╩══╩══╩══╩══╩═
#                                                                                                                                         9                         6                0  1  2  3  4  5  7  8

# %% [markdown]
# #### Note that fake backend is discontinued in Qiskit 1. So we shall continue with real backends for this example

# %%
service = QiskitRuntimeService()

# %%
all_backends = [service.get_backend('ibm_brisbane'), service.get_backend('ibm_osaka'), service.get_backend('ibm_kyoto')]

# %%
backend = all_backends[0]
backend
# Out:
# <IBMBackend('ibm_brisbane')>

# %% [markdown]
# #### First we transpile

# %%
pm = generate_preset_pass_manager(2, backend=backend)

# %%
trans_qc = pm.run(qc)

# %%
trans_qc.draw(fold=-1, idle_wires=False) # this hides the unnecessary ancilla qubits
# Out:
# global phase: 5.0974
#                ┌────┐     ┌──────────┐                ┌──────┐     ┌────┐                                                  ┌──────┐        ┌────┐                                                                                                                                                 ┌──────┐ ┌────────┐   ┌────┐   ┌─────────┐ ┌──────┐   ┌────┐   ┌──────────┐  ┌──────┐ ┌──────────┐┌────┐┌─────────┐             ┌─┐
#  q_2 -> 0 ─────┤ √X ├─────┤ Rz(-π/2) ├────────────────┤1     ├─────┤ √X ├──────────────────────────────────────────────────┤1     ├────────┤ √X ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├─┤ Rz(-π) ├───┤ √X ├───┤ Rz(π/2) ├─┤1     ├───┤ √X ├───┤ Rz(-π/2) ├──┤1     ├─┤ Rz(-π/2) ├┤ √X ├┤ Rz(π/2) ├─────────────┤M├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#             ┌──┴────┴──┐  └──┬────┬──┘   ┌────────┐   │  Ecr │  ┌──┴────┴──┐      ┌────┐     ┌─────────────┐   ┌────┐      │  Ecr │      ┌─┴────┴─┐     ┌────┐     ┌─────────┐  ┌──────┐     ┌────┐     ┌─────────────┐                        ┌──────┐  ┌──────────┐    ┌────┐    ┌─────────────┐│  Ecr │┌┴────────┤   ├────┤   └─────────┘ │  Ecr │┌──┴────┴──┐└──┬────┬──┘  │  Ecr │ └┬────────┬┘├────┤└─────────┘             └╥┘                                                                                                                                                                                                                                                                                                                    ┌──────┐  ┌────────┐   ┌────┐   ┌─────────┐ ┌──────┐   ┌────┐   ┌──────────┐  ┌──────┐    ┌────┐                                                                                                                                                                                                        ┌──────┐   ┌────────┐   ┌────┐   ┌─────────┐  ┌──────┐         ┌─┐
#  q_7 -> 1 ──┤ Rz(-π/2) ├─────┤ √X ├──────┤ Rz(-π) ├───┤0     ├──┤ Rz(-π/2) ├──────┤ √X ├─────┤ Rz(-1.6859) ├───┤ √X ├──────┤0     ├──────┤ Rz(-π) ├─────┤ √X ├─────┤ Rz(π/2) ├──┤1     ├─────┤ √X ├─────┤ Rz(-2.3791) ├────────────────────────┤1     ├──┤ Rz(-π/2) ├────┤ √X ├────┤ Rz(-2.6866) ├┤0     ├┤ Rz(π/2) ├───┤ √X ├───────────────┤0     ├┤ Rz(-π/2) ├───┤ √X ├─────┤0     ├──┤ Rz(-π) ├─┤ √X ├─────────────────────────╫─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├──┤ Rz(-π) ├───┤ √X ├───┤ Rz(π/2) ├─┤1     ├───┤ √X ├───┤ Rz(-π/2) ├──┤1     ├────┤ √X ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├───┤ Rz(-π) ├───┤ √X ├───┤ Rz(π/2) ├──┤1     ├─────────┤M├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#             └┬────────┬┘     ├────┤      ├────────┤   ├──────┤ ┌┴──────────┴┐     ├────┤     └──┬────────┬─┘  ┌┴────┴┐ ┌───┴──────┴──┐   └─┬────┬─┘   ┌─┴────┴─┐   └─────────┘  │  Ecr │     ├────┤     └┬────────────┤   ┌────┐  ┌─────────┐  │  Ecr │  ├──────────┤    ├────┤    └┬───────────┬┘└┬────┬┘└─┬──────┬┘   ├────┤   ┌──────────┐├──────┤└┬────────┬┘   ├────┤   ┌─┴──────┴┐ └┬──────┬┘ ├────┤┌──────────┐             ║                                                                                                                                                                                                                                                                                   ┌──────┐    ┌───┐   ┌──────────┐  │  Ecr │ ┌┴────────┤   ├────┤   └─────────┘ │  Ecr │┌──┴────┴──┐└──┬────┬──┘  │  Ecr │  ┌─┴────┴─┐    ┌────┐                                                                                                          ┌──────┐┌────┐                               ┌──────┐  ┌───┐   ┌──────────────┐   │  Ecr │  ┌┴────────┤   ├────┤   └─────────┘  │  Ecr │  ┌───┐  └╥┘            ┌─┐
#  q_6 -> 2 ───┤ Rz(-π) ├──────┤ √X ├──────┤ Rz(-π) ├───┤1     ├─┤ Rz(2.0496) ├─────┤ √X ├────────┤ Rz(-π) ├────┤1     ├─┤ Rz(0.23842) ├─────┤ √X ├─────┤ Rz(-π) ├────────────────┤0     ├─────┤ √X ├──────┤ Rz(2.3791) ├───┤ √X ├──┤ Rz(π/2) ├──┤0     ├──┤ Rz(-π/2) ├────┤ √X ├─────┤ Rz(2.288) ├──┤ √X ├───┤1     ├────┤ √X ├───┤ Rz(-π/2) ├┤1     ├─┤ Rz(-π) ├────┤ √X ├───┤ Rz(π/2) ├──┤1     ├──┤ √X ├┤ Rz(-π/2) ├─────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├────┤ X ├───┤ Rz(-π/2) ├──┤0     ├─┤ Rz(π/2) ├───┤ √X ├───────────────┤0     ├┤ Rz(-π/2) ├───┤ √X ├─────┤0     ├──┤ Rz(-π) ├────┤ √X ├──────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├┤ √X ├───────────────────────────────┤1     ├──┤ X ├───┤ Rz(-0.59756) ├───┤0     ├──┤ Rz(π/2) ├───┤ √X ├────────────────┤0     ├──┤ X ├───╫─────────────┤M├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#           ┌──┴────────┴──┐   └────┘      └────────┘   │  Ecr │ └───┬───┬────┘  ┌──┴────┴──┐     └────────┘    │  Ecr │ └──┬────────┬─┘     ├────┤     ├────────┤     ┌──────┐   └┬────┬┘┌────┴────┴───┐  └────────────┘   └────┘  └─┬──────┬┘┌─┴──────┴─┐└──────────┘    └────┘     └───────────┘  └────┘   │  Ecr │ ┌──┴────┴──┐└──┬────┬──┘│  Ecr │┌┴────────┤    ├────┤   └─────────┘  │  Ecr │  ├────┤└─┬──────┬─┘┌──────────┐ ║    ┌────┐   ┌────────┐┌──────┐┌───────────┐┌────┐   ┌────────┐                                                                                                     ┌──────┐   ┌────┐   ┌──────────┐  ┌──────┐  ┌────────┐   ┌────┐   ┌─────────┐ ┌──────┐   ┌───┐    ┌─────────┐  │  Ecr │  ┌─┴───┴──┐└──┬────┬──┘ ┌┴──────┴┐└─────────┘   └────┘               └──────┘└──────────┘   └────┘     ├──────┤  └─┬────┬─┘ ┌──┴────┴──┐  ┌──────┐   ┌────────┐   ┌────┐  ┌─────────┐  ┌──────┐  ┌────┐  ┌────────────┐   ┌────┐   ┌──────────┐│  Ecr │├────┤┌────────────┐┌────┐┌─────────┐│  Ecr │┌─┴───┴──┐└────┬────┬────┘┌──┴──────┴─┐└─┬──────┬┘┌──┴────┴──┐   ┌────┐   ┌┴──────┴┐┌┴───┴─┐ ║ ┌──────────┐└╥┘┌────┐┌─────────┐           ┌─┐
#  q_8 -> 3 ┤ Rz(-0.47879) ├────────────────────────────┤0     ├─────┤ X ├───────┤ Rz(-π/2) ├───────────────────┤0     ├────┤ Rz(-π) ├───────┤ √X ├─────┤ Rz(-π) ├─────┤1     ├────┤ √X ├─┤ Rz(-1.4078) ├─────────────────────────────┤1     ├─┤ Rz(-π/2) ├───────────────────────────────────────────────────┤0     ├─┤ Rz(-π/2) ├───┤ √X ├───┤0     ├┤ Rz(π/2) ├────┤ √X ├────────────────┤0     ├──┤ √X ├──┤1     ├──┤ Rz(3π/4) ├─╫────┤ √X ├───┤ Rz(-π) ├┤1     ├┤ Rz(-3π/4) ├┤ √X ├───┤ Rz(-π) ├─────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├───┤ √X ├───┤ Rz(-π/2) ├──┤1     ├──┤ Rz(-π) ├───┤ √X ├───┤ Rz(π/2) ├─┤1     ├───┤ X ├────┤ Rz(π/2) ├──┤0     ├──┤ Rz(-π) ├───┤ √X ├────┤ Rz(-π) ├─────────────────────────────────────────────────────────────────────┤1     ├────┤ √X ├───┤ Rz(-π/2) ├──┤1     ├───┤ Rz(-π) ├───┤ √X ├──┤ Rz(π/2) ├──┤1     ├──┤ √X ├──┤ Rz(0.1639) ├───┤ √X ├───┤ Rz(-π/2) ├┤0     ├┤ √X ├┤ Rz(1.7347) ├┤ √X ├┤ Rz(π/2) ├┤0     ├┤ Rz(-π) ├─────┤ √X ├─────┤ Rz(1.813) ├──┤1     ├─┤ Rz(3π/4) ├───┤ √X ├───┤ Rz(-π) ├┤1     ├─╫─┤ Rz(3π/4) ├─╫─┤ √X ├┤ Rz(π/2) ├───────────┤M├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#           ├──────────────┤   ┌────┐   ┌─────────────┐ └┬────┬┘     └───┘       └──────────┘                   └──────┘    └────────┘       └────┘     └────────┘     │  Ecr │    ├────┤ └┬────────────┤      ┌────┐    ┌─────────┐  │  Ecr │ ├─────────┬┘   ┌────┐   ┌────────────┐                         └──────┘ └──────────┘   └────┘   └──────┘└─────────┘    └────┘                └──────┘  └────┘  │  Ecr │  └──┬───┬───┘ ║ ┌──┴────┴──┐└────────┘│  Ecr │└┬──────────┤├────┤┌──┴────────┴─┐┌──────┐┌─────────┐┌────┐           ┌──────┐┌──────────┐   ┌────┐   ┌──────┐┌─────────┐   ┌────┐   │  Ecr │┌──┴────┴──┐└──┬────┬──┘  │  Ecr │ ┌┴────────┤   ├────┤   └─────────┘ │  Ecr │┌──┴───┴───┐└──┬────┬─┘  ├──────┤ ┌┴────────┤   ├────┤    └────────┘  ┌──────┐ ┌──────────┐   ┌────┐   ┌──────┐┌─────────┐    ┌────┐     │  Ecr │ ┌──┴────┴──┐└──┬────┬──┘  │  Ecr │  ┌┴────────┤   ├────┤  └─────────┘  │  Ecr │  ├───┬┘  └┬──────────┬┘   └────┘   └──────────┘└──────┘└────┘└────────────┘└────┘└─────────┘└──────┘└────────┘     └────┘     └───────────┘  │  Ecr │ └──┬───┬───┘┌──┴────┴──┐└────────┘│  Ecr │ ║ ├──────────┤ ║ ├────┤└─┬──────┬┘┌─────────┐└╥┘┌────┐           ┌──────┐┌──────────┐   ┌────┐   ┌──────┐┌─────────┐ ┌────┐┌────────────┐┌──────┐     ┌───┐     ┌──────────┐               ┌──────┐    ┌───┐     ┌──────────┐               ┌─┐
#  q_5 -> 4 ┤ Rz(-0.60012) ├───┤ √X ├───┤ Rz(-1.6627) ├──┤ √X ├────────────────────────────────────────────────────────────────────────────────────────────────────────┤0     ├────┤ √X ├──┤ Rz(1.4078) ├──────┤ √X ├────┤ Rz(π/2) ├──┤0     ├─┤ Rz(π/2) ├────┤ √X ├───┤ Rz(2.8097) ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0     ├─────┤ X ├─────╫─┤ Rz(-π/2) ├──────────┤0     ├─┤ Rz(-π/2) ├┤ √X ├┤ Rz(-3.0624) ├┤0     ├┤ Rz(π/2) ├┤ √X ├───────────┤0     ├┤ Rz(-π/2) ├───┤ √X ├───┤0     ├┤ Rz(π/2) ├───┤ √X ├───┤0     ├┤ Rz(-π/2) ├───┤ √X ├─────┤0     ├─┤ Rz(π/2) ├───┤ √X ├───────────────┤0     ├┤ Rz(-π/2) ├───┤ √X ├────┤0     ├─┤ Rz(π/2) ├───┤ √X ├────────────────┤0     ├─┤ Rz(-π/2) ├───┤ √X ├───┤0     ├┤ Rz(π/2) ├────┤ √X ├─────┤0     ├─┤ Rz(-π/2) ├───┤ √X ├─────┤0     ├──┤ Rz(π/2) ├───┤ √X ├───────────────┤0     ├──┤ X ├────┤ Rz(-π/4) ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0     ├────┤ X ├────┤ Rz(-π/2) ├──────────┤0     ├─╫─┤ Rz(-π/2) ├─╫─┤ √X ├──┤0     ├─┤ Rz(π/2) ├─╫─┤ √X ├───────────┤0     ├┤ Rz(-π/2) ├───┤ √X ├───┤0     ├┤ Rz(π/2) ├─┤ √X ├┤ Rz(-1.838) ├┤0     ├─────┤ X ├─────┤ Rz(-π/2) ├───────────────┤0     ├────┤ X ├─────┤ Rz(-π/4) ├───────────────┤M├─────────────────────────────────────────────────────────────────────────────────────────
#           └────┬────┬────┘   └────┘   └─────────────┘ ┌┴────┴┐     ┌────┐    ┌──────────────┐                              ┌──────┐        ┌────┐    ┌──────────┐    └──────┘    └────┘  └────────────┘      └────┘    └─────────┘  └──────┘ └─────────┘    └────┘   └────────────┘                                                                                                                         └──────┘     └───┘     ║ └──────────┘          └──────┘ └──────────┘└────┘└─────────────┘│      │└─────────┘└────┘           │      │└──────────┘   └────┘   │      │└─────────┘   └────┘   └──────┘└──────────┘   └────┘     └──────┘ └─────────┘   └────┘               └──────┘└──────────┘   └────┘    │  Ecr │ └┬────────┤   ├────┤   ┌─────────┐  │  Ecr │ └──┬────┬──┘┌──┴────┴──┐│  Ecr │└┬────────┤    ├────┤   ┌─┴──────┴┐└─┬──────┬─┘   ├────┤   ┌─┴──────┴─┐└─┬──────┬┘ ┌─┴────┴─┐   ┌────┐  ┌─┴──────┴┐┌┴───┴─┐┌─┴──────────┴┐   ┌────┐    ┌────────┐                                                                                               └──────┘    └───┘    └──────────┘          └──────┘ ║ └──────────┘ ║ └────┘  │      │ └─────────┘ ║ └────┘           │      │└──────────┘   └────┘   │      │└─────────┘ └────┘└────────────┘│  Ecr │┌────┴───┴────┐└──┬────┬──┘┌─────────────┐│  Ecr │┌───┴───┴────┐└──┬────┬──┘┌─────────────┐└╥┘┌────┐┌──────────────┐┌──────┐┌──────────┐   ┌────┐   ┌────────┐┌──────┐┌─────────┐┌─┐
#  q_3 -> 5 ─────┤ √X ├─────────────────────────────────┤1     ├─────┤ √X ├────┤ Rz(-0.33002) ├──────────────────────────────┤1     ├────────┤ √X ├────┤ Rz(-π/2) ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫─────────────────────────────────────────────────────────────────┤      ├────────────────────────────┤      ├────────────────────────┤      ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├──┤ Rz(-π) ├───┤ √X ├───┤ Rz(π/2) ├──┤1     ├────┤ √X ├───┤ Rz(-π/2) ├┤1     ├─┤ Rz(-π) ├────┤ √X ├───┤ Rz(π/2) ├──┤1     ├─────┤ √X ├───┤ Rz(-π/2) ├──┤1     ├──┤ Rz(-π) ├───┤ √X ├──┤ Rz(π/2) ├┤1     ├┤ Rz(-1.7557) ├───┤ √X ├────┤ Rz(-π) ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫──────────────╫─────────┤      ├─────────────╫──────────────────┤      ├────────────────────────┤      ├────────────────────────────────┤1     ├┤ Rz(-1.3036) ├───┤ √X ├───┤ Rz(-2.4298) ├┤1     ├┤ Rz(1.5084) ├───┤ √X ├───┤ Rz(-1.5171) ├─╫─┤ √X ├┤ Rz(-0.86071) ├┤1     ├┤ Rz(3π/4) ├───┤ √X ├───┤ Rz(-π) ├┤1     ├┤ Rz(π/4) ├┤M├───
#           ┌────┴────┴───┐    ┌────┐      ┌────────┐   │  Ecr │     ├────┤    ├─────────────┬┘     ┌────┐    ┌─────────┐    │  Ecr │    ┌───┴────┴───┐└──┬────┬──┘┌─────────────┐ ┌────┐ ┌─────────────┐                                                                                                                                                                                                                            ║                                                                 │  Ecr │                            │  Ecr │                        │  Ecr │                                                                                                                                      └──────┘  └────────┘   └────┘   └─────────┘  └──────┘    └────┘   └──────────┘└──────┘ └────────┘    └────┘   └─────────┘  │  Ecr │  ┌──┴────┴──┐└──┬────┬──┘  │  Ecr │ ┌┴────────┤   ├────┤  └─────────┘│  Ecr │└────┬───┬────┘┌──┴────┴──┐ └────────┘                                                                                                                                                   ║              ║         │  Ecr │             ║                  │  Ecr │                        │  Ecr │                                └──────┘└─────────────┘   └────┘   └─────────────┘└──────┘└────────────┘   └────┘   └─────────────┘ ║ └────┘└──────────────┘│  Ecr │└──┬───┬───┘┌──┴────┴──┐└────────┘│  Ecr │└──┬───┬──┘└╥┘┌─┐
#  q_1 -> 6 ┤ Rz(-2.4835) ├────┤ √X ├──────┤ Rz(-π) ├───┤0     ├─────┤ √X ├────┤ Rz(0.33002) ├──────┤ √X ├────┤ Rz(π/2) ├────┤0     ├────┤ Rz(1.2466) ├───┤ √X ├───┤ Rz(-2.2032) ├─┤ √X ├─┤ Rz(-2.9455) ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫─────────────────────────────────────────────────────────────────┤      ├────────────────────────────┤      ├────────────────────────┤      ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0     ├──┤ Rz(-π/2) ├───┤ √X ├─────┤0     ├─┤ Rz(π/2) ├───┤ √X ├─────────────┤0     ├─────┤ X ├─────┤ Rz(-π/4) ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫──────────────╫─────────┤      ├─────────────╫──────────────────┤      ├────────────────────────┤      ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫───────────────────────┤0     ├───┤ X ├────┤ Rz(-π/2) ├──────────┤0     ├───┤ X ├────╫─┤M├
#           └────┬────┬───┘    └────┘      └────────┘   └──────┘    ┌┴────┴┐   └────┬───┬────┘   ┌──┴────┴──┐ └─────────┘    ├──────┤   ┌┴────────────┤   ├────┤   └┬────────────┤ ├────┤ ├─────────────┴┐                                                                                                                                                                                                                           ║                                                                 │      │ ┌────────┐┌────┐┌─────────┐│      │   ┌────┐   ┌──────────┐│      │   ┌───┐   ┌──────────┐┌──────┐┌─────────┐    ┌────┐                ┌──────┐ ┌──────────┐   ┌────┐   ┌──────┐ ┌────────┐    ┌────┐                                                                                                                               └──────┘  └──────────┘   └────┘     └──────┘ └─────────┘   └────┘             └──────┘     └───┘     └──────────┘                                                                                                                                                              ║              ║         │      │  ┌────────┐ ║ ┌────┐┌─────────┐│      │   ┌────┐   ┌──────────┐│      │┌──────────┐┌────┐ ┌─────────┐    ┌─┐                                                                                               ║                       └──────┘   └───┘    └──────────┘          └──────┘   └───┘    ║ └╥┘
# q_0 -> 15 ─────┤ √X ├─────────────────────────────────────────────┤0     ├────────┤ X ├────────┤ Rz(-π/2) ├────────────────┤0     ├───┤ Rz(-2.3551) ├───┤ √X ├────┤ Rz(-1.757) ├─┤ √X ├─┤ Rz(-0.78647) ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫─────────────────────────────────────────────────────────────────┤1     ├─┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├┤1     ├───┤ √X ├───┤ Rz(-π/2) ├┤1     ├───┤ X ├───┤ Rz(-π/2) ├┤0     ├┤ Rz(π/2) ├────┤ √X ├────────────────┤0     ├─┤ Rz(-π/2) ├───┤ √X ├───┤0     ├─┤ Rz(-π) ├────┤ √X ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫──────────────╫─────────┤1     ├──┤ Rz(-π) ├─╫─┤ √X ├┤ Rz(π/2) ├┤1     ├───┤ √X ├───┤ Rz(-π/2) ├┤1     ├┤ Rz(-π/2) ├┤ √X ├─┤ Rz(π/2) ├────┤M├───────────────────────────────────────────────────────────────────────────────────────────────╫─────────────────────────────────────────────────────────────────────────────────────╫──╫─
#                ├────┤     ┌─────────┐      ┌────┐    ┌────────┐   │      │        └───┘        └──────────┘                │      │   └─────────────┘  ┌┴────┴┐   └┬─────────┬─┘ ├────┤ └─┬──────────┬─┘      ┌─┐                                                                                                                                                                                                                  ║                                                                 └──────┘ └────────┘└────┘└─────────┘└──────┘   └────┘   └──────────┘└──────┘   └───┘   └──────────┘│      │└─────────┘    └────┘                │      │ └──────────┘   └────┘   │      │ └────────┘    └────┘                                                                                                                                                                                                                                                                                                                                                                                                              ║              ║         └──────┘  └────────┘ ║ └────┘└─────────┘└──────┘   └────┘   └──────────┘└──────┘└──────────┘└────┘ └─────────┘    └╥┘                                                                                               ║                                                                                     ║  ║
# q_9 -> 21 ─────┤ √X ├─────┤ Rz(π/4) ├──────┤ √X ├────┤ Rz(-π) ├───┤  Ecr ├─────────────────────────────────────────────────┤  Ecr ├────────────────────┤0     ├────┤ Rz(π/2) ├───┤ √X ├───┤ Rz(3π/4) ├────────┤M├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤  Ecr ├─────────────────────────────────────┤  Ecr ├─────────────────────────┤  Ecr ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫──────────────╫──────────────────────────────╫─────────────────────────────────────────────────────────────────────────────────────────────╫────────────────────────────────────────────────────────────────────────────────────────────────╫─────────────────────────────────────────────────────────────────────────────────────╫──╫─
#             ┌──┴────┴──┐  └──┬────┬─┘   ┌──┴────┴─┐  └────────┘   │      │   ┌─────────────┐      ┌────┐     ┌────────┐    │      │      ┌────────┐    │  Ecr │    └──┬────┬─┘   └────┘   └──────────┘        └╥┘                                                                                                                                                                                                                  ║                                                                                                                                                                    │      │ ┌────────┐    ┌────┐   ┌─────────┐  │      │    ┌────┐   ┌──────────┐│      │┌──────────┐   ┌────┐  ┌─────────┐    ┌─┐                                                                                                                                                                                                                                                                                                                                                                                          ║              ║                              ║                                                                                             ║                                                                                                ║                                                                                     ║  ║
# q_4 -> 22 ──┤ Rz(-π/2) ├─────┤ √X ├─────┤ Rz(π/2) ├───────────────┤1     ├───┤ Rz(-2.0476) ├──────┤ √X ├─────┤ Rz(-π) ├────┤1     ├──────┤ Rz(-π) ├────┤1     ├───────┤ √X ├───────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├─┤ Rz(-π) ├────┤ √X ├───┤ Rz(π/2) ├──┤1     ├────┤ √X ├───┤ Rz(-π/2) ├┤1     ├┤ Rz(-π/2) ├───┤ √X ├──┤ Rz(π/2) ├────┤M├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫──────────────╫──────────────────────────────╫─────────────────────────────────────────────────────────────────────────────────────────────╫────────────────────────────────────────────────────────────────────────────────────────────────╫─────────────────────────────────────────────────────────────────────────────────────╫──╫─
#             └──────────┘     └────┘     └─────────┘               └──────┘   └─────────────┘      └────┘     └────────┘    └──────┘      └────────┘    └──────┘       └────┘                                   ║                                                                                                                                                                                                                   ║                                                                                                                                                                    └──────┘ └────────┘    └────┘   └─────────┘  └──────┘    └────┘   └──────────┘└──────┘└──────────┘   └────┘  └─────────┘    └╥┘                                                                                                                                                                                                                                                                                                                                                                                          ║              ║                              ║                                                                                             ║                                                                                                ║                                                                                     ║  ║
#     c: 10/═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══════════════╩══════════════════════════════╩═════════════════════════════════════════════════════════════════════════════════════════════╩════════════════════════════════════════════════════════════════════════════════════════════════╩═════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                                                                                                                                9                                                                                                                                                                                                                   7                                                                                                                                                                                                                                                                                                 5                                                                                                                                                                                                                                                                                                                                                                                           8              2                              3                                                                                             0                                                                                                4                                                                                     1  6

# %% [markdown]
# #### Now we shall find all the subgraph isomorphisms

# %%
small_qc = mm.deflate_circuit(trans_qc)
layouts = mm.matching_layouts(small_qc, backend)

# %%
layouts
# Out:
# [[0, 1, 2, 3, 4, 5, 6, 15, 21, 22],
#  [24, 25, 26, 27, 28, 29, 30, 35, 46, 47],
#  [24, 25, 26, 27, 28, 29, 30, 35, 48, 47]]

# %%
scores = mm.evaluate_layouts(small_qc, layouts, backend)

# %%
scores
# Out:
# [([0, 1, 2, 3, 4, 5, 6, 15, 21, 22], 0.43055225822131793),
#  ([24, 25, 26, 27, 28, 29, 30, 35, 46, 47], 0.6239273009398256),
#  ([24, 25, 26, 27, 28, 29, 30, 35, 48, 47], 0.6252818875395343)]

# %%
mm_pm = generate_preset_pass_manager(2, backend, initial_layout=scores[0][0])
mm_qc = mm_pm.run(qc)

# %%
mm_qc.draw(fold=-1, idle_wires=False)
# Out:
# global phase: 5.0974
#                ┌────┐     ┌──────────┐                                                                                                                                                                                                                                                                               ┌──────┐    ┌────────┐    ┌────┐  ┌─────────┐  ┌──────┐     ┌────┐   ┌──────────┐  ┌──────┐      ┌────┐                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ┌──────┐   ┌────────┐     ┌────┐  ┌─────────┐  ┌──────┐    ┌────┐   ┌──────────┐┌──────┐┌──────────┐┌────┐┌─────────┐           ┌─┐
#  q_0 -> 0 ─────┤ √X ├─────┤ Rz(-π/2) ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├────┤ Rz(-π) ├────┤ √X ├──┤ Rz(π/2) ├──┤1     ├─────┤ √X ├───┤ Rz(-π/2) ├──┤1     ├──────┤ √X ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├───┤ Rz(-π) ├─────┤ √X ├──┤ Rz(π/2) ├──┤1     ├────┤ √X ├───┤ Rz(-π/2) ├┤1     ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(π/2) ├───────────┤M├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#            ┌───┴────┴───┐ └──┬────┬──┘   ┌────────┐                                                                                                                        ┌──────┐ ┌────────┐     ┌────┐    ┌─────────────┐              ┌──────┐  ┌─────────────┐ ┌────┐ ┌─────────────┐   ┌────┐   ┌─────────┐    │  Ecr │   ┌┴────────┤    ├────┤  └─────────┘  │  Ecr │  ┌──┴────┴──┐└──┬────┬──┘  │  Ecr │   ┌──┴────┴──┐               ┌──────┐    ┌────┐                                                ┌──────┐    ┌────────────┐   ┌────┐   ┌────────────┐ ┌────┐ ┌─────────────┐                                                                                            ┌──────┐    ┌────────┐   ┌────┐  ┌─────────┐    ┌──────┐      ┌────┐   ┌──────────┐┌──────┐   ┌────┐    ┌────────┐                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ┌──────┐  ┌──────────┐   ┌────┐   ┌────────┐  ┌──────┐    ┌───┐    ┌─────────┐ │  Ecr │  ┌┴────────┤     ├────┤  └─────────┘  │  Ecr │ ┌──┴────┴──┐└──┬────┬──┘│  Ecr │└┬────────┬┘├────┤└─┬──────┬┘ ┌────────┐└╥┘┌────┐┌─────────┐┌──────┐   ┌────┐   ┌──────────┐┌──────┐┌──────────┐┌────┐┌─────────┐           ┌─┐
#  q_1 -> 1 ─┤ Rz(2.2289) ├────┤ √X ├──────┤ Rz(-π) ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├─┤ Rz(-π) ├─────┤ √X ├────┤ Rz(-2.8116) ├──────────────┤1     ├──┤ Rz(-2.2289) ├─┤ √X ├─┤ Rz(-2.8818) ├───┤ √X ├───┤ Rz(π/2) ├────┤0     ├───┤ Rz(π/2) ├────┤ √X ├───────────────┤0     ├──┤ Rz(-π/2) ├───┤ √X ├─────┤0     ├───┤ Rz(-π/2) ├───────────────┤1     ├────┤ √X ├────────────────────────────────────────────────┤1     ├────┤ Rz(1.8309) ├───┤ √X ├───┤ Rz(-2.338) ├─┤ √X ├─┤ Rz(-2.5399) ├────────────────────────────────────────────────────────────────────────────────────────────┤1     ├────┤ Rz(-π) ├───┤ √X ├──┤ Rz(π/2) ├────┤1     ├──────┤ √X ├───┤ Rz(-π/2) ├┤1     ├───┤ √X ├────┤ Rz(-π) ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├──┤ Rz(3π/4) ├───┤ √X ├───┤ Rz(-π) ├──┤1     ├────┤ X ├────┤ Rz(π/4) ├─┤0     ├──┤ Rz(π/2) ├─────┤ √X ├───────────────┤0     ├─┤ Rz(-π/2) ├───┤ √X ├───┤0     ├─┤ Rz(-π) ├─┤ √X ├──┤1     ├──┤ Rz(-π) ├─╫─┤ √X ├┤ Rz(π/2) ├┤1     ├───┤ √X ├───┤ Rz(-π/2) ├┤1     ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(π/2) ├───────────┤M├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#            └───┬────┬───┘ ┌──┴────┴──┐   └────────┘    ┌──────┐   ┌────────┐    ┌────┐   ┌─────────┐ ┌──────┐   ┌────┐   ┌──────────┐  ┌──────┐    ┌───┐      ┌─────────┐  │  Ecr │ └─┬────┬─┘┌────┴────┴───┐└────┬────┬───┘┌──────────┐  │  Ecr │  └──┬────────┬─┘ ├────┤ └─────────────┘   └────┘   └─┬──────┬┘   ┌┴──────┴┐  └──┬────┬─┘ ┌──┴────┴─┐  ┌──────┐   └┬────┬┘  ├──────────┤  ┌┴────┴┐  ┌─┴──────┴┐  └──┬────┬──┘ ┌──────────┐  │  Ecr │ ┌──┴────┴──┐     ┌────┐    ┌────────────┐   ┌────┐       │  Ecr │    └┬─────────┬─┘   ├────┤   └┬──────────┬┘┌┴────┴┐└──┬────────┬─┘ ┌────┐ ┌─────────┐   ┌──────┐     ┌────┐   ┌──────────┐┌──────┐    ┌───┐    ┌──────────┐   │  Ecr │   ┌┴────────┤   ├────┤  └─────────┘    │  Ecr │   ┌──┴────┴──┐└──┬────┬──┘│  Ecr │ ┌─┴────┴─┐  └─┬────┬─┘ ┌────────┐                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ┌──────┐  ┌─────────┐   ┌────┐   ┌─────────┐  │  Ecr │  └──┬───┬───┘┌──┴────┴──┐└────────┘  │  Ecr │ ┌──┴───┴───┐└──┬────┬─┘ └──────┘  └─────────┘     └────┘               └──────┘ └──────────┘   └────┘   └──────┘ └────────┘ └────┘  │  Ecr │ ┌┴────────┤ ║ ├────┤└─────────┘│  Ecr │┌──┴────┴──┐└──┬────┬──┘│  Ecr │└┬────────┬┘├────┤└─┬──────┬┘ ┌────────┐└╥┘┌────┐┌─────────┐┌──────┐   ┌────┐   ┌──────────┐┌──────┐┌──────────┐┌────┐┌─────────┐           ┌─┐
#  q_2 -> 2 ─────┤ √X ├─────┤ Rz(-π/2) ├─────────────────┤1     ├───┤ Rz(-π) ├────┤ √X ├───┤ Rz(π/2) ├─┤1     ├───┤ √X ├───┤ Rz(-π/2) ├──┤1     ├────┤ X ├──────┤ Rz(π/2) ├──┤0     ├───┤ √X ├──┤ Rz(0.33002) ├─────┤ √X ├────┤ Rz(-π/2) ├──┤0     ├─────┤ Rz(-π) ├───┤ √X ├──────────────────────────────┤1     ├────┤ Rz(-π) ├─────┤ √X ├───┤ Rz(π/2) ├──┤1     ├────┤ √X ├───┤ Rz(-π/2) ├──┤1     ├──┤ Rz(π/2) ├─────┤ √X ├────┤ Rz(-π/2) ├──┤0     ├─┤ Rz(-π/2) ├─────┤ √X ├────┤ Rz(-1.094) ├───┤ √X ├───────┤0     ├─────┤ Rz(π/2) ├─────┤ √X ├────┤ Rz(-π/2) ├─┤1     ├───┤ Rz(-π) ├───┤ √X ├─┤ Rz(π/2) ├───┤1     ├─────┤ √X ├───┤ Rz(-π/2) ├┤1     ├────┤ X ├────┤ Rz(-π/2) ├───┤0     ├───┤ Rz(π/2) ├───┤ √X ├─────────────────┤0     ├───┤ Rz(-π/2) ├───┤ √X ├───┤0     ├─┤ Rz(-π) ├────┤ √X ├───┤ Rz(-π) ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├──┤ Rz(π/2) ├───┤ √X ├───┤ Rz(π/4) ├──┤0     ├─────┤ X ├────┤ Rz(-π/2) ├────────────┤0     ├─┤ Rz(-π/2) ├───┤ √X ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0     ├─┤ Rz(π/2) ├─╫─┤ √X ├───────────┤0     ├┤ Rz(-π/2) ├───┤ √X ├───┤0     ├─┤ Rz(-π) ├─┤ √X ├──┤1     ├──┤ Rz(-π) ├─╫─┤ √X ├┤ Rz(π/2) ├┤1     ├───┤ √X ├───┤ Rz(-π/2) ├┤1     ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(π/2) ├───────────┤M├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#             ┌──┴────┴──┐  └──┬────┬──┘   ┌────────┐    │  Ecr │  ┌┴────────┤    ├────┤   └─────────┘ │  Ecr │┌──┴────┴──┐└──┬────┬──┘  │  Ecr │  ┌─┴───┴──┐   └──┬────┬─┘  ├──────┤ ┌─┴────┴─┐└────┬────┬───┘  ┌──┴────┴─┐  └─┬──────┬─┘  └┬────┬┘    ┌┴────────┴┐ ┌┴────┴┐     ┌───┐     ┌──────────┐  │  Ecr │   ┌┴────────┤     ├────┤   └─────────┘  │  Ecr │ ┌──┴────┴──┐└──┬────┬──┘  │  Ecr │  └──┬────┬─┘┌────┴────┴───┐└─┬──────┬─┘ ┌┴──────┴┐└──┬────┬──┘┌────┴────┴───┐└──┬──────┬──┘   ├────┤   ┌───┴──────┴──┐  └──┬────┬─┘  ┌──┴────┴──┐ └──────────┘ │  Ecr │  ┌┴────────┤   ├────┤ └─────────┘   │  Ecr │  ┌──┴────┴──┐└──┬────┬──┘│  Ecr │  ┌─┴───┴──┐ └──┬────┬──┘   └──────┘   └─────────┘   └────┘                 └──────┘   └──────────┘   └────┘   └──────┘ └────────┘    └────┘   └────────┘                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ┌──────┐  ┌────────┐   ┌────┐   ┌─────────┐  ┌──────┐    ┌────┐   ┌──────────┐┌──────┐  ┌──────────┐ ┌────┐  │  Ecr │  └┬────────┤   ├────┤   ├─────────┤  └──────┘     └───┘    └──────────┘            └──────┘ └──────────┘   └────┘               ┌──────┐    ┌────────┐   ┌────┐  ┌─────────┐  ┌──────┐  ┌──────────┐ ┌────┐  ┌────────┐         └──────┘ └─────────┘ ║ └────┘           └──────┘└──────────┘   └────┘   └──────┘ └────────┘ └────┘  │  Ecr │ ┌┴────────┤ ║ ├────┤└─────────┘│  Ecr │┌──┴────┴──┐└──┬────┬──┘│  Ecr │└┬────────┬┘├────┤└─┬──────┬┘ ┌────────┐└╥┘┌────┐┌─────────┐┌──────┐   ┌────┐   ┌──────────┐┌──────┐┌──────────┐┌────┐  ┌─────────┐        ┌─┐
#  q_3 -> 3 ──┤ Rz(-π/2) ├─────┤ √X ├──────┤ Rz(-π) ├────┤0     ├──┤ Rz(π/2) ├────┤ √X ├───────────────┤0     ├┤ Rz(-π/2) ├───┤ √X ├─────┤0     ├──┤ Rz(-π) ├──────┤ √X ├────┤1     ├─┤ Rz(-π) ├─────┤ √X ├──────┤ Rz(π/2) ├────┤1     ├─────┤ √X ├─────┤ Rz(-π/2) ├─┤1     ├─────┤ X ├─────┤ Rz(-π/2) ├──┤0     ├───┤ Rz(π/2) ├─────┤ √X ├────────────────┤0     ├─┤ Rz(-π/2) ├───┤ √X ├─────┤0     ├─────┤ √X ├──┤ Rz(-0.1639) ├──┤1     ├───┤ Rz(-π) ├───┤ √X ├───┤ Rz(-1.4069) ├───┤1     ├──────┤ √X ├───┤ Rz(-2.8994) ├─────┤ √X ├────┤ Rz(-π/2) ├──────────────┤0     ├──┤ Rz(π/2) ├───┤ √X ├───────────────┤0     ├──┤ Rz(-π/2) ├───┤ √X ├───┤0     ├──┤ Rz(-π) ├────┤ √X ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├──┤ Rz(-π) ├───┤ √X ├───┤ Rz(π/2) ├──┤1     ├────┤ √X ├───┤ Rz(-π/2) ├┤1     ├──┤ Rz(-π/2) ├─┤ √X ├──┤0     ├───┤ Rz(-π) ├───┤ √X ├───┤ Rz(π/2) ├─────────────────────────────────────────────────────────────────────────────────────────────┤1     ├────┤ Rz(-π) ├───┤ √X ├──┤ Rz(π/2) ├──┤1     ├──┤ Rz(-π/2) ├─┤ √X ├──┤ Rz(-π) ├──────────────────────────────╫──────────────────────────────────────────────────────────────────────────────┤0     ├─┤ Rz(π/2) ├─╫─┤ √X ├───────────┤0     ├┤ Rz(-π/2) ├───┤ √X ├───┤0     ├─┤ Rz(-π) ├─┤ √X ├──┤1     ├──┤ Rz(-π) ├─╫─┤ √X ├┤ Rz(π/2) ├┤1     ├───┤ √X ├───┤ Rz(-π/2) ├┤1     ├┤ Rz(-π/2) ├┤ √X ├──┤ Rz(π/2) ├────────┤M├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#             ├──────────┤     ├────┤      ├────────┤    └──────┘  └─────────┘    └────┘               └──────┘└──────────┘   └────┘     └──────┘  └────────┘      └────┘    │  Ecr │┌┴────────┤     ├────┤      └─────────┘    │  Ecr │  ┌──┴────┴──┐  └──┬────┬──┘ │  Ecr │  ┌──┴───┴──┐  └──┬────┬──┘  ├──────┤   └──┬───┬──┘  ┌──┴────┴──┐             ├──────┤ └──┬───┬───┘┌──┴────┴──┐  └──────┘     └────┘  └─────────────┘  │  Ecr │   └─┬───┬──┘┌──┴────┴──┐└─────────────┘   │  Ecr │   ┌──┴────┴──┐└────┬────┬───┘┌────┴────┴───┐└─┬──────┬─┘ ┌─────────┐  └┬────┬┘  └─────────┘  ┌┴────┴┐┌──────────┐  └┬────┬┘  └─┬──────┬─┘┌──┴────┴─┐ └┬────┬┘┌─┴────────┴┐  ┌┴────┴┐      ┌───┐     ┌──────────┐            ┌──────┐      ┌───┐     ┌──────────┐            ┌──────┐┌──────────┐   ┌────┐    ┌──────┐ ┌─────────┐┌────┐           ┌──────┐┌───┐ ┌──────────┐      ┌──────┐  ┌──────────┐    ┌────┐              ┌──────┐┌─────────┐   ┌────┐                           ┌──────┐  ┌──────────┐  ┌────┐                                                                                                                    ┌──────┐┌─────────┐    ┌────┐                ┌──────┐ ┌──────────┐   ┌────┐   ┌──────┐┌─────────┐   ┌────┐    ┌──────┐ ┌──────────┐   ┌────┐   ┌──────┐┌─────────┐┌────┐           ┌──────┐┌──────────┐┌────┐ │  Ecr │ ┌┴────────┤   ├────┤   └─────────┘  │  Ecr │ ┌──┴────┴──┐└──┬────┬──┘│  Ecr │  ├─────────┬┘ ├────┤  └──────┘   └┬──────┬┘┌──┴────┴──┐└──┬────┬─┘              ┌──────┐  ┌─────────┐   ┌────┐               ┌──────┐  ┌──────────┐ ┌────┐     │  Ecr │   ┌┴────────┤   ├────┤  └─────────┘  │  Ecr │  ├──────────┤ ├────┤  └────────┘                              ║                                                                              └──────┘ └─────────┘ ║ └────┘           └──────┘└──────────┘   └────┘   └──────┘ └────────┘ └────┘  │  Ecr │ ┌┴────────┤ ║ ├────┤└─────────┘│  Ecr │┌──┴────┴──┐└──┬────┬──┘│  Ecr │├──────────┤├────┤┌─┴─────────┴─┐┌────┐└╥┘┌──────┐┌─────────────┐┌────┐┌─────────────┐┌────┐┌─────────────┐┌──────┐┌─────────────┐┌────┐┌─────────────┐┌────┐┌────────────┐┌──────┐┌──────────┐┌────┐┌─────────┐┌────┐┌──────┐┌─────────┐ ┌────┐┌──────────┐┌─┐
#  q_4 -> 4 ──┤ Rz(-π/2) ├─────┤ √X ├──────┤ Rz(-π) ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0     ├┤ Rz(π/2) ├─────┤ √X ├─────────────────────┤0     ├──┤ Rz(-π/2) ├─────┤ √X ├────┤0     ├──┤ Rz(π/2) ├─────┤ √X ├─────┤0     ├──────┤ X ├─────┤ Rz(-π/2) ├─────────────┤0     ├────┤ X ├────┤ Rz(-π/2) ├────────────────────────────────────────┤0     ├─────┤ X ├───┤ Rz(-π/2) ├──────────────────┤0     ├───┤ Rz(-π/2) ├─────┤ √X ├────┤ Rz(0.97324) ├──┤0     ├───┤ Rz(π/2) ├───┤ √X ├────────────────┤0     ├┤ Rz(-π/2) ├───┤ √X ├─────┤0     ├──┤ Rz(π/2) ├──┤ √X ├─┤ Rz(1.092) ├──┤0     ├──────┤ X ├─────┤ Rz(-π/2) ├────────────┤0     ├──────┤ X ├─────┤ Rz(-π/2) ├────────────┤0     ├┤ Rz(-π/2) ├───┤ √X ├────┤0     ├─┤ Rz(π/2) ├┤ √X ├───────────┤0     ├┤ X ├─┤ Rz(-π/2) ├──────┤0     ├──┤ Rz(-π/2) ├────┤ √X ├──────────────┤0     ├┤ Rz(π/2) ├───┤ √X ├───────────────────────────┤0     ├──┤ Rz(-π/2) ├──┤ √X ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0     ├┤ Rz(π/2) ├────┤ √X ├────────────────┤0     ├─┤ Rz(-π/2) ├───┤ √X ├───┤0     ├┤ Rz(π/2) ├───┤ √X ├────┤0     ├─┤ Rz(-π/2) ├───┤ √X ├───┤0     ├┤ Rz(π/2) ├┤ √X ├───────────┤0     ├┤ Rz(-π/2) ├┤ √X ├─┤0     ├─┤ Rz(π/2) ├───┤ √X ├────────────────┤0     ├─┤ Rz(-π/2) ├───┤ √X ├───┤0     ├──┤ Rz(π/2) ├──┤ √X ├──────────────┤0     ├─┤ Rz(-π/2) ├───┤ √X ├────────────────┤0     ├──┤ Rz(π/2) ├───┤ √X ├───────────────┤0     ├──┤ Rz(-π/2) ├─┤ √X ├─────┤0     ├───┤ Rz(π/2) ├───┤ √X ├───────────────┤0     ├──┤ Rz(-π/2) ├─┤ √X ├──────────────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────╫──────────────────────────────────────────────────────────────────────────────┤0     ├─┤ Rz(π/2) ├─╫─┤ √X ├───────────┤0     ├┤ Rz(-π/2) ├───┤ √X ├───┤0     ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(-1.3859) ├┤ √X ├─╫─┤0     ├┤ Rz(-2.3005) ├┤ √X ├┤ Rz(-1.7721) ├┤ √X ├┤ Rz(0.17695) ├┤0     ├┤ Rz(-3.0159) ├┤ √X ├┤ Rz(-2.4259) ├┤ √X ├┤ Rz(1.4758) ├┤0     ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(π/4) ├┤ √X ├┤0     ├┤ Rz(π/2) ├─┤ √X ├┤ Rz(3π/4) ├┤M├───
#           ┌─┴──────────┴─┐   ├────┤   ┌──┴────────┴─┐   ┌────┐     ┌──────┐     ┌────┐   ┌──────────┐┌──────┐ ┌────────┐    ┌────┐   ┌─────────┐  ┌──────┐     ┌────────┐  └┬────┬┘└┬────────┤     └────┘                     └──────┘  └──────────┘     └────┘    └──────┘  └─────────┘     └────┘     │      │      └───┘     └──────────┘             │      │    └───┘    └──────────┘                                        └──────┘     └───┘   └──────────┘                  └──────┘   └──────────┘     └────┘    └─────────────┘  │      │   └─────────┘   └────┘                │      │└──────────┘   └────┘     │      │  └─────────┘  └────┘ └───────────┘  │  Ecr │  ┌───┴───┴────┐└──┬────┬──┘┌────────┐  │  Ecr │ ┌────┴───┴────┐└──┬────┬──┘ ┌────────┐ │  Ecr │└──┬────┬──┘┌──┴────┴──┐ │  Ecr │ └┬────────┤├────┤┌─────────┐│  Ecr │├───┴┐└─┬──────┬─┘┌────┐│      │┌─┴──────────┴┐   └────┘              │      │└─┬──────┬┘ ┌─┴────┴─┐   ┌────┐    ┌────────┐  │      │  └──────────┘  └────┘                                                                                                                    │      │└─────────┘    └────┘                │      │ └──────────┘   └────┘   │      │└─────────┘   └────┘    │  Ecr │ └──┬────┬──┘┌──┴────┴──┐│  Ecr │└┬────────┤├────┤┌─────────┐│  Ecr │└┬────────┬┘├────┤┌┴──────┴┐└─┬──────┬┘┌──┴────┴──┐   ┌────┐   ┌┴──────┴┐└─┬──────┬─┘┌──┴────┴─┐ └┬────┬┘  ├─────────┴┐ └────┘              │      │ └──────────┘   └────┘                │      │  └─────────┘   └────┘               │      │  └──────────┘ └────┘     └──────┘   └─────────┘   └────┘               └──────┘  └──────────┘ └────┘                                          ║                                                                                                   ║                                                                              └──────┘ └─────────┘ ║ └────┘           └──────┘└──────────┘   └────┘   └──────┘└──────────┘└────┘└─────────────┘└────┘ ║ │      │└─────────────┘└────┘└─────────────┘└────┘└─────────────┘│      │└─────────────┘└────┘└─────────────┘└────┘└────────────┘│  Ecr │└──┬────┬──┘└────┘└─────────┘└────┘│  Ecr │├─────────┴┐├────┤├─────────┬┘└╥┘┌─┐
#  q_5 -> 5 ┤ Rz(-0.60012) ├───┤ √X ├───┤ Rz(-2.1161) ├───┤ √X ├─────┤1     ├─────┤ √X ├───┤ Rz(-π/2) ├┤1     ├─┤ Rz(-π) ├────┤ √X ├───┤ Rz(π/2) ├──┤1     ├─────┤ Rz(-π) ├───┤ √X ├──┤ Rz(-π) ├──────────────────────────────────────────────────────────────────────────────────────────────────────────┤      ├─────────────────────────────────────────┤      ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤      ├───────────────────────────────────────┤      ├──────────────────────────┤      ├─────────────────────────────────────┤1     ├──┤ Rz(2.0496) ├───┤ √X ├───┤ Rz(-π) ├──┤1     ├─┤ Rz(-2.0496) ├───┤ √X ├────┤ Rz(-π) ├─┤1     ├───┤ √X ├───┤ Rz(-π/2) ├─┤1     ├──┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├┤1     ├┤ √X ├──┤1     ├──┤ √X ├┤      ├┤ Rz(-1.4078) ├───────────────────────┤      ├──┤1     ├──┤ Rz(-π) ├───┤ √X ├────┤ Rz(-π) ├──┤      ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤      ├─────────────────────────────────────┤      ├─────────────────────────┤      ├────────────────────────┤1     ├────┤ √X ├───┤ Rz(-π/2) ├┤1     ├─┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├┤1     ├─┤ Rz(-π) ├─┤ √X ├┤ Rz(-π) ├──┤1     ├─┤ Rz(3π/4) ├───┤ √X ├───┤ Rz(-π) ├──┤1     ├──┤ Rz(π/2) ├──┤ √X ├───┤ Rz(-π/2) ├─────────────────────┤      ├──────────────────────────────────────┤      ├─────────────────────────────────────┤      ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────╫──────────────────────────────────────────────────────────────────────────────────────────────────╫─┤      ├─────────────────────────────────────────────────────────┤      ├────────────────────────────────────────────────────────┤1     ├───┤ √X ├──────────────────────────┤1     ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(π/2) ├──╫─┤M├
#           └─┬──────────┬─┘   └────┘   └─────────────┘   └────┘     │  Ecr │  ┌──┴────┴──┐└──┬────┬──┘│  Ecr │┌┴────────┤    ├────┤   └─────────┘  │  Ecr │  ┌──┴────────┴─┐ ├────┤  └────────┘                                                                                                          │  Ecr │                                         │  Ecr │                                                                                                                                                                           │  Ecr │                                       │  Ecr │                          │  Ecr │                                     └──────┘  └────────────┘   └────┘   └────────┘  └──────┘ └─────────────┘   └────┘    └────────┘ └──────┘   └────┘   └──────────┘ └──────┘  └────────┘└────┘└─────────┘└──────┘└────┘  │  Ecr │  ├────┤│  Ecr │└┬────────────┤   ┌────┐   ┌─────────┐│  Ecr │  │  Ecr │ ┌┴────────┤   ├────┤  ┌─┴────────┴─┐│  Ecr │                                                                                                                                          │  Ecr │                                     │  Ecr │                         │  Ecr │                        └──────┘    └────┘   └──────────┘└──────┘ └────────┘└────┘└─────────┘└──────┘ └────────┘ └────┘└────────┘  │  Ecr │ └──┬───┬───┘┌──┴────┴──┐└────────┘  │  Ecr │  ├─────────┴┐ ├────┤ ┌─┴──────────┴┐┌────┐┌──────────┐  │  Ecr │                 ┌─┐                  │  Ecr │                                     │  Ecr │                                                                                                                                               ║                                                                                                   ║                                                                                                   ║                                                                                                  ║ │  Ecr │                                                         │  Ecr │                                                        └──────┘   └────┘                          └──────┘└──────────┘└────┘└─────────┘  ║ └╥┘
#  q_6 -> 6 ──┤ Rz(-π/2) ├───────────────────────────────────────────┤0     ├──┤ Rz(-π/2) ├───┤ √X ├───┤0     ├┤ Rz(π/2) ├────┤ √X ├────────────────┤0     ├──┤ Rz(0.45346) ├─┤ √X ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤      ├─────────────────────────────────────────┤      ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤      ├───────────────────────────────────────┤      ├──────────────────────────┤      ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0     ├──┤ √X ├┤      ├─┤ Rz(1.4078) ├───┤ √X ├───┤ Rz(π/2) ├┤      ├──┤0     ├─┤ Rz(π/2) ├───┤ √X ├──┤ Rz(2.8097) ├┤      ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤      ├─────────────────────────────────────┤      ├─────────────────────────┤      ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0     ├────┤ X ├────┤ Rz(-π/2) ├────────────┤0     ├──┤ Rz(-π/2) ├─┤ √X ├─┤ Rz(-3.0624) ├┤ √X ├┤ Rz(-π/2) ├──┤      ├─────────────────┤M├──────────────────┤      ├─────────────────────────────────────┤      ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────╫──────────────────────────────────────────────────────────────────────────────────────────────────╫─┤      ├─────────────────────────────────────────────────────────┤      ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫──╫─
#             └┬────────┬┘     ┌────┐      ┌────────┐                └──────┘  └──────────┘   └────┘   └──────┘└─────────┘    └────┘                └──────┘  └─────────────┘ └────┘                                                                                                                      │      │ ┌─────────────┐   ┌────┐    ┌────────┐  │      │ ┌──────────┐   ┌────┐    ┌────────┐   ┌──────┐   ┌─────────┐     ┌────┐                ┌──────┐    ┌──────────┐     ┌────┐      ┌──────┐     ┌────────┐       ┌────┐      │      │    ┌────────┐   ┌────┐   ┌─────────┐  │      │   ┌────┐   ┌──────────┐  │      │   ┌────────┐  ┌────┐  ┌─────────┐                                                                                                                                                                                         └──────┘  └────┘│      │ └───┬────┬───┘┌──┴────┴──┐└─────────┘│      │ ┌┴──────┴┐└──┬────┬─┘┌──┴────┴─┐└────────────┘│      │┌──────────────┐┌────┐┌────────┐┌──────┐┌────┐ ┌────────────┐┌────┐┌─────────┐┌──────┐┌──────────┐┌────┐┌──────────────┐┌────┐┌─────────┐ │      │ ┌────────┐    ┌────┐   ┌─────────┐  │      │    ┌────┐   ┌──────────┐│      │ ┌────────┐   ┌────┐  ┌─────────┐                                                                                                  └──────┘    └───┘    └──────────┘            └──────┘  └──────────┘ └────┘ └─────────────┘└────┘└──────────┘  │      │    ┌────┐       └╥┘    ┌──────────┐  │      │   ┌────────┐   ┌────┐  ┌─────────┐  │      │  ┌──────────┐┌──────┐┌─────────────┐   ┌────┐  ┌─────────┐                                                                                    ║                                                                                                   ║                                                                                                   ║                                                                                                  ║ │      │     ┌────┐                                              │      │  ┌──────────┐ ┌────┐  ┌─────────┐   ┌─┐                                                                                                  ║  ║
# q_7 -> 15 ───┤ Rz(-π) ├──────┤ √X ├──────┤ Rz(-π) ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├─┤ Rz(-1.4557) ├───┤ √X ├────┤ Rz(-π) ├──┤1     ├─┤ Rz(-π/2) ├───┤ √X ├────┤ Rz(-π) ├───┤0     ├───┤ Rz(π/2) ├─────┤ √X ├────────────────┤0     ├────┤ Rz(-π/2) ├─────┤ √X ├──────┤0     ├─────┤ Rz(-π) ├───────┤ √X ├──────┤1     ├────┤ Rz(-π) ├───┤ √X ├───┤ Rz(π/2) ├──┤1     ├───┤ √X ├───┤ Rz(-π/2) ├──┤1     ├───┤ Rz(-π) ├──┤ √X ├──┤ Rz(π/2) ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├─────┤ √X ├────┤ Rz(-π/2) ├───────────┤1     ├─┤ Rz(-π) ├───┤ √X ├──┤ Rz(π/2) ├──────────────┤1     ├┤ Rz(-0.85359) ├┤ √X ├┤ Rz(-π) ├┤0     ├┤ √X ├─┤ Rz(2.3791) ├┤ √X ├┤ Rz(π/2) ├┤0     ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(-0.85359) ├┤ √X ├┤ Rz(π/2) ├─┤1     ├─┤ Rz(-π) ├────┤ √X ├───┤ Rz(π/2) ├──┤1     ├────┤ √X ├───┤ Rz(-π/2) ├┤1     ├─┤ Rz(-π) ├───┤ √X ├──┤ Rz(π/2) ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├────┤ √X ├────────╫─────┤ Rz(-π/2) ├──┤1     ├───┤ Rz(-π) ├───┤ √X ├──┤ Rz(π/2) ├──┤1     ├──┤ Rz(-π/2) ├┤0     ├┤ Rz(-1.3036) ├───┤ √X ├──┤ Rz(π/2) ├────────────────────────────────────────────────────────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────╫──────────────────────────────────────────────────────────────────────────────────────────────────╫─┤1     ├─────┤ √X ├──────────────────────────────────────────────┤1     ├──┤ Rz(-π/2) ├─┤ √X ├──┤ Rz(π/4) ├───┤M├──────────────────────────────────────────────────────────────────────────────────────────────────╫──╫─
#             ┌┴────────┴┐     └────┘      └┬──────┬┘  ┌──────────┐   ┌────┐     ┌──────┐  ┌─────────┐  ┌────┐               ┌──────┐     ┌───┐   ┌──────────┐                                                                                                                                            └──────┘ └─────────────┘   └────┘    └────────┘  └──────┘ └──────────┘   └────┘    └────────┘   │      │   └─────────┘     └────┘                │      │    └──────────┘     └────┘      │      │     └────────┘       └────┘      └──────┘    └────────┘   └────┘   └─────────┘  └──────┘   └────┘   └──────────┘  └──────┘   └────────┘  └────┘  └─────────┘                                                                                                                                                                                                         └──────┘     └────┘    └──────────┘           └──────┘ └────────┘   └────┘  └─────────┘              └──────┘└──────────────┘└────┘└────────┘│      │└────┘ └────────────┘└────┘└─────────┘│      │└──────────┘└────┘└──────────────┘└────┘└─────────┘ ├──────┤┌┴────────┴┐   ├────┤   └─┬──────┬┘┌─┴──────┴┐   ├────┤   └──────────┘├──────┤ └─┬───┬──┘   └────┘  └───┬─┬───┘                                                                                                                                                                                                                └──────┘    └────┘        ║     └──────────┘  └──────┘   └────────┘   └────┘  └─────────┘  └──────┘  └──────────┘│      │└─────────────┘   └────┘  └─────────┘                                                                                    ║                                                                                                   ║                                                                                                   ║                                                                                                  ║ └──────┘     └────┘                                              └──────┘  └──────────┘ └────┘  └─────────┘   └╥┘                                                                                                  ║  ║
# q_8 -> 21 ──┤ Rz(-π/2) ├──────────────────┤0     ├───┤ Rz(-π/2) ├───┤ √X ├─────┤0     ├──┤ Rz(π/2) ├──┤ √X ├───────────────┤0     ├─────┤ X ├───┤ Rz(-π/2) ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤  Ecr ├─────────────────────────────────────────┤  Ecr ├─────────────────────────────────┤  Ecr ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤  Ecr ├──────────────────────────────────────┤  Ecr ├────────────────────────────────────────────────────┤0     ├┤ Rz(-π/2) ├───┤ √X ├─────┤0     ├─┤ Rz(π/2) ├───┤ √X ├───────────────┤0     ├───┤ X ├──────────────────┤M├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫──────────────────────────────────────────────────────────────────────────────────────┤  Ecr ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────╫──────────────────────────────────────────────────────────────────────────────────────────────────╫────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────╫──╫─
#             └──┬────┬──┘   ┌────────┐     │  Ecr │   └──┬────┬──┘┌──┴────┴──┐  │  Ecr │  └┬────────┤  ├────┤ ┌─────────┐   │  Ecr │     ├───┴┐  ├──────────┤                                                                                                                                                                                                                                            │      │    ┌────────┐     ┌────┐   ┌─────────┐  │      │       ┌────┐     ┌──────────┐   │      │       ┌────┐      ┌─────────┐                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │      │┌────┐┌─────────────┐                 │      │┌──────────┐┌────┐┌─────────────┐ ┌────┐┌──────────┐│  Ecr │└──┬────┬──┘┌──┴────┴──┐  │  Ecr │ └┬────────┤   ├────┤   ┌─────────┐ │  Ecr │   ├───┴┐  ┌─────────┐    └╥┘       ┌────┐                                                                                                                                                                                                                                 ║                                                                                      │      │  ┌─────────┐      ┌─┐                                                                                                   ║                                                                                                   ║                                                                                                   ║                                                                                                  ║                                                                                                                ║                                                                                                   ║  ║
# q_9 -> 22 ─────┤ √X ├──────┤ Rz(-π) ├─────┤1     ├──────┤ √X ├───┤ Rz(-π/2) ├──┤1     ├───┤ Rz(-π) ├──┤ √X ├─┤ Rz(π/2) ├───┤1     ├─────┤ √X ├──┤ Rz(-π/2) ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├────┤ Rz(-π) ├─────┤ √X ├───┤ Rz(π/2) ├──┤1     ├───────┤ √X ├─────┤ Rz(-π/2) ├───┤1     ├───────┤ √X ├──────┤ Rz(π/2) ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1     ├┤ √X ├┤ Rz(-2.3791) ├─────────────────┤1     ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(-1.1158) ├─┤ √X ├┤ Rz(-π/2) ├┤1     ├───┤ √X ├───┤ Rz(-π/2) ├──┤1     ├──┤ Rz(-π) ├───┤ √X ├───┤ Rz(π/2) ├─┤1     ├───┤ √X ├──┤ Rz(π/4) ├─────╫────────┤ √X ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫──────────────────────────────────────────────────────────────────────────────────────┤1     ├──┤ Rz(π/4) ├──────┤M├───────────────────────────────────────────────────────────────────────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────╫──────────────────────────────────────────────────────────────────────────────────────────────────╫────────────────────────────────────────────────────────────────────────────────────────────────────────────────╫───────────────────────────────────────────────────────────────────────────────────────────────────╫──╫─
#                └────┘      └────────┘     └──────┘      └────┘   └──────────┘  └──────┘   └────────┘  └────┘ └─────────┘   └──────┘     └────┘  └──────────┘                                                                                                                                                                                                                                            └──────┘    └────────┘     └────┘   └─────────┘  └──────┘       └────┘     └──────────┘   └──────┘       └────┘      └─────────┘                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     └──────┘└────┘└─────────────┘                 └──────┘└──────────┘└────┘└─────────────┘ └────┘└──────────┘└──────┘   └────┘   └──────────┘  └──────┘  └────────┘   └────┘   └─────────┘ └──────┘   └────┘  └─────────┘     ║        └────┘                                                                                                                                                                                                                                 ║                                                                                      └──────┘  └─────────┘      └╥┘                                                                                                   ║                                                                                                   ║                                                                                                   ║                                                                                                  ║                                                                                                                ║                                                                                                   ║  ║
#     c: 10/══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩════════════════════════════════════════════════════════════════════════════════════════════════════╩═══════════════════════════════════════════════════════════════════════════════════════════════════╩═══════════════════════════════════════════════════════════════════════════════════════════════════╩══════════════════════════════════════════════════════════════════════════════════════════════════╩════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩═══════════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         7                                                                                                                                                                                                                                               5                                                                                                                  9                                                                                                    3                                                                                                   0                                                                                                   8                                                                                                  2                                                                                                                4                                                                                                   1  6

# %% [markdown]
# ### Finding the best backend using mapomatic

# %%
layouts_hw = mm.best_overall_layout(small_qc, backends, successors=True)

# %%
layouts_hw
# Out:
# [([0, 1, 2, 3, 4, 5, 6, 15, 21, 22], 'ibm_brisbane', 0.43055225822131793),
#  ([4, 15, 22, 23, 24, 34, 43, 25, 27, 26], 'ibm_osaka', 0.48177782473249353),
#  ([100, 99, 98, 97, 96, 95, 94, 109, 115, 114],
#   'ibm_kyoto',
#   0.5553818210650094)]

# %% [markdown]
# We note that brisbane itself is the best backend out of the three. However, this method could have been used to select a better backend if there were any.
